# %%
"""
Your task in this exercise has two steps:

- audit the OSMFILE and change the variable 'mapping' to reflect the changes needed to fix 
    the unexpected street types to the appropriate ones in the expected list.
    You have to add mappings only for the actual problems you find in this OSMFILE,
    not a generalized solution, since that may and will depend on the particular area you are auditing.
- write the update_name function, to actually fix the street name.
    The function takes a string with street name as an argument and should return the fixed name
    We have provided a simple test so that you see what exactly is expected
"""
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

OSMFILE = "OSM/atlanta_georgia_subset.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons","Drive"]

# UPDATE THIS VARIABLE
mapping = { "St": "Street",
            "St.": "Street",
            "Ave":"Avenue",
            "Rd.":"Road",
           "Dr":"Drive"
            }


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types


def update_name(name, mapping):
    street=street_type_re.search(name).group()
    if street not in expected:
        if street in mapping:
            name=name.replace(street,mapping[street])

    return name


def test():
    st_types = audit(OSMFILE)
    pprint.pprint(dict(st_types))

    for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, mapping)
            print name, "=>", better_name
            if name == "West Lexington St.":
                assert better_name == "West Lexington Street"
            if name == "Baldwin Rd.":
                assert better_name == "Baldwin Road"


if __name__ == '__main__':
    test()
# Out:
# {'136': set(['GA 136']),
#  '41': set(['US 41']),
#  '53': set(['GA 53']),
#  'Bluff': set(['Wheatridge Bluff']),
#  'Chute': set(['Briers Chute']),
#  'Circle': set(['Crabapple Lake Circle',
#                 'Estate Club Circle',
#                 'Greenmont Circle',
#                 'Harvest Circle',
#                 'Jennifer Oaks Circle',
#                 'Quay Circle',
#                 'Saddle Creek Circle',
#                 'Sweet Apple Circle']),
#  'Close': set(['Callan Close', 'Hughes Branch Close']),
#  'Connector': set(['GA 136 Connector']),
#  'Downs': set(['Barrow Downs']),
#  'Dr': set(['Billings Dr']),
#  'Highway': set(['Birmingham Highway',
#                  'Old Dixie Highway',
#                  'West Bankhead Highway']),
#  'Hill': set(['Blueberry Hill']),
#  'Hollow': set(['Hickory Oak Hollow']),
#  'Northeast': set(['Dixie Avenue Northeast',
#                    'Druid Circle Northeast',
#                    'Heritage Drive Northeast',
#                    'Meadowvale Drive Northeast',
#                    'Pickens Industrial Drive Northeast',
#                    'Piedmont Avenue Northeast']),
#  'Northwest': set(['Busbee Drive Northwest',
#                    'Gateway Drive Northwest',
#                    'North River Street Northwest']),
#  'Point': set(['Mountain Point']),
#  'Run': set(['Squirrel Run']),
#  'Southeast': set(['Franklin Loop Southeast',
#                    'Freys Gin Road Southeast',
#                    'Jackson Street Southeast',
#                    'Peeples Valley Road Southeast',
#                    'Powers Ferry Road Southeast']),
#  'Steeplechase': set(['Steeplechase']),
#  'Terrace': set(['Shade Tree Terrace', 'Walnut Terrace']),
#  'Trace': set(['Bridle Ridge Trace',
#                'Camber Trace',
#                'Farm Grove Trace',
#                'Saddle Ridge Trace',
#                'Spearfield Trace',
#                'Sweetwater Trace',
#                'Welford Trace']),
#  'Walk': set(['Garden Walk', 'Greenmont Walk', 'Sydney Walk']),
#  'Way': set(['Baywood Way',
#              'Brassfield Way',
#              'Canberra Way',
#              'Crabapple Parc Way',
#              'Edenbrooke Way',
#              'Foxley Way',
#              'Innovation Way',
#              'Kingsworth Way',
#              'Shade Tree Way',
#              'Vistacrest Way',
#              'Water Garden Way',
#              'Willow View Way'])}
# Druid Circle Northeast => Druid Circle Northeast
# Dixie Avenue Northeast => Dixie Avenue Northeast
# Pickens Industrial Drive Northeast => Pickens Industrial Drive Northeast
# Meadowvale Drive Northeast => Meadowvale Drive Northeast
# Piedmont Avenue Northeast => Piedmont Avenue Northeast
# Heritage Drive Northeast => Heritage Drive Northeast
# GA 136 Connector => GA 136 Connector
# GA 136 => GA 136
# Crabapple Parc Way => Crabapple Parc Way
# Willow View Way => Willow View Way
# Foxley Way => Foxley Way
# Water Garden Way => Water Garden Way
# Vistacrest Way => Vistacrest Way
# Innovation Way => Innovation Way
# Edenbrooke Way => Edenbrooke Way
# Shade Tree Way => Shade Tree Way
# Brassfield Way => Brassfield Way
# Kingsworth Way => Kingsworth Way
# Baywood Way => Baywood Way
# Canberra Way => Canberra Way
# Estate Club Circle => Estate Club Circle
# Harvest Circle => Harvest Circle
# Jennifer Oaks Circle => Jennifer Oaks Circle
# Greenmont Circle => Greenmont Circle
# Sweet Apple Circle => Sweet Apple Circle
# Saddle Creek Circle => Saddle Creek Circle
# Quay Circle => Quay Circle
# Crabapple Lake Circle => Crabapple Lake Circle
# Hickory Oak Hollow => Hickory Oak Hollow
# Blueberry Hill => Blueberry Hill
# West Bankhead Highway => West Bankhead Highway
# Birmingham Highway => Birmingham Highway
# Old Dixie Highway => Old Dixie Highway
# Squirrel Run => Squirrel Run
# Farm Grove Trace => Farm Grove Trace
# Bridle Ridge Trace => Bridle Ridge Trace
# Camber Trace => Camber Trace
# Sweetwater Trace => Sweetwater Trace
# Welford Trace => Welford Trace
# Spearfield Trace => Spearfield Trace
# Saddle Ridge Trace => Saddle Ridge Trace
# Barrow Downs => Barrow Downs
# US 41 => US 41
# Franklin Loop Southeast => Franklin Loop Southeast
# Powers Ferry Road Southeast => Powers Ferry Road Southeast
# Jackson Street Southeast => Jackson Street Southeast
# Peeples Valley Road Southeast => Peeples Valley Road Southeast
# Freys Gin Road Southeast => Freys Gin Road Southeast
# Wheatridge Bluff => Wheatridge Bluff
# Billings Dr => Billings Drive
# Briers Chute => Briers Chute
# Steeplechase => Steeplechase
# Mountain Point => Mountain Point
# GA 53 => GA 53
# Greenmont Walk => Greenmont Walk
# Garden Walk => Garden Walk
# Sydney Walk => Sydney Walk
# Shade Tree Terrace => Shade Tree Terrace
# Walnut Terrace => Walnut Terrace
# Hughes Branch Close => Hughes Branch Close
# Callan Close => Callan Close
# Busbee Drive Northwest => Busbee Drive Northwest
# North River Street Northwest => North River Street Northwest
# Gateway Drive Northwest => Gateway Drive Northwest
